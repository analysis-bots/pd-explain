# %%
# !pip install pd-explain

# %%
import pandas as pd
import pd_explain
# Out:
# usetex-False

# %% [markdown]
# # Bank Churners Dataset
#
#
# **CLIENTNUM** : Client number. Unique identifier for the customer holding the account
#
# **Attrition_Flag :** Internal event (customer activity) variable - if the account is closed then 1 else 0
#
# **Dependent_count :** Demographic variable - Number of dependents
#
# **Total_Relationship_Count :** Total no. of products held by the customer
#
# **Total_Revolving_Bal :** Total Revolving Balance on the Credit Card
#
# **Avg_Open_To_Buy :** Open to Buy Credit Line (Average of last 12 months)
#
# **Months_on_book :** Period of relationship with bank
#
# **Months_Inactive_12_mon :** No. of months inactive in the last 12 months
#
# **Contacts_Count_12_mon :** No. of Contacts in the last 12 months
#
# **Total_Amt_Chng_Q4_Q1 :** Change in Transaction Amount (Q4 over Q1)
#
# **Total_Trans_Amt :** Total Transaction Amount (Last 12 months)
#
# **Total_Trans_Ct :** Total Transaction Count (Last 12 months)
#
# **Total_Ct_Chng_Q4_Q1 :** Change in Transaction Count (Q4 over Q1)
#
# **Avg_Utilization_Ratio :** Average Card Utilization Ratio

# %%
credit_card_customers = (pd.read_csv(r"..\Datasets\bank_churners_user_study.csv"))

# %%
type(credit_card_customers)
# Out:
# pd_explain.core.explainable_data_frame.ExpDataFrame

# %%
credit_card_customers
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Months_Inactive_Count_Last_Year  \
# 0                  39  ...                                1
# 1                  44  ...                                1
# 2                  36  ...                                1
# 3                  34  ...                                4
# 4                  21  ...                                1
# ...               ...  ...                              ...
# 10122              40  ...                                2
# 10123              25  ...                                2
# 10124              36  ...                                3
# 10125              36  ...                                3
# 10126              25  ...                                2
#
#        Contacts_Count_Last_Year  Credit_Limit  Credit_Used  \
# 0                             3       12691.0          777
# 1                             2        8256.0          864
# 2                             0        3418.0            0
# 3                             1        3313.0         2517
# 4                             0        4716.0            0
# ...                         ...           ...          ...
# 10122                         3        4003.0         1851
# 10123                         3        4277.0         2186
# 10124                         4        5409.0            0
# 10125                         3        5281.0            0
# 10126                         4       10388.0         1961
#
#        Credit_Open_To_Buy  Total_Amount_Change_Q4_vs_Q1  \
# 0                 11914.0                         1.335
# 1                  7392.0                         1.541
# 2                  3418.0                         2.594
# 3                   796.0                         1.405
# 4                  4716.0                         2.175
# ...                   ...                           ...
# 10122              2152.0                         0.703
# 10123              2091.0                         0.804
# 10124              5409.0                         0.819
# 10125              5281.0                         0.535
# 10126              8427.0                         0.703
#
#        Total_Transitions_Amount  Total_Transitions_Count  \
# 0                          1144                       42
# 1                          1291                       33
# 2                          1887                       20
# 3                          1171                       20
# 4                           816                       28
# ...                         ...                      ...
# 10122                     15476                      117
# 10123                      8764                       69
# 10124                     10291                       60
# 10125                      8395                       62
# 10126                     10294                       61
#
#        Total_Count_Change_Q4_vs_Q1  Credit_Avg_Utilization_Ratio
# 0                            1.625                         0.061
# 1                            3.714                         0.105
# 2                            2.333                         0.000
# 3                            2.333                         0.760
# 4                            2.500                         0.000
# ...                            ...                           ...
# 10122                        0.857                         0.462
# 10123                        0.683                         0.511
# 10124                        0.818                         0.000
# 10125                        0.722                         0.000
# 10126                        0.649                         0.189
#
# [10127 rows x 21 columns]

# %% [markdown]
# # OPERATION #1

# %%
# filter_results = credit_card_customers[credit_card_customers["Customer_Age"] > 45]
filter_results = credit_card_customers.where(credit_card_customers["Customer_Age"] > 45)
explains = filter_results.explain(attributes=['Months_on_book', 'Gender'], show_scores=True)

# %%
filter_results
# Out:
#          CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0              NaN                NaN           NaN    NaN              NaN
# 1      818770008.0  Existing Customer          49.0      F              5.0
# 2      713982108.0  Existing Customer          51.0      M              3.0
# 3              NaN                NaN           NaN    NaN              NaN
# 4              NaN                NaN           NaN    NaN              NaN
# ...            ...                ...           ...    ...              ...
# 10122  772366833.0  Existing Customer          50.0      M              2.0
# 10123          NaN                NaN           NaN    NaN              NaN
# 10124          NaN                NaN           NaN    NaN              NaN
# 10125          NaN                NaN           NaN    NaN              NaN
# 10126          NaN                NaN           NaN    NaN              NaN
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0                 NaN            NaN             NaN           NaN
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3                 NaN            NaN             NaN           NaN
# 4                 NaN            NaN             NaN           NaN
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123             NaN            NaN             NaN           NaN
# 10124             NaN            NaN             NaN           NaN
# 10125             NaN            NaN             NaN           NaN
# 10126             NaN            NaN             NaN           NaN
#
#        Months_on_book  ...  Months_Inactive_Count_Last_Year  \
# 0                 NaN  ...                              NaN
# 1                44.0  ...                              1.0
# 2                36.0  ...                              1.0
# 3                 NaN  ...                              NaN
# 4                 NaN  ...                              NaN
# ...               ...  ...                              ...
# 10122            40.0  ...                              2.0
# 10123             NaN  ...                              NaN
# 10124             NaN  ...                              NaN
# 10125             NaN  ...                              NaN
# 10126             NaN  ...                              NaN
#
#        Contacts_Count_Last_Year  Credit_Limit  Credit_Used  \
# 0                           NaN           NaN          NaN
# 1                           2.0        8256.0        864.0
# 2                           0.0        3418.0          0.0
# 3                           NaN           NaN          NaN
# 4                           NaN           NaN          NaN
# ...                         ...           ...          ...
# 10122                       3.0        4003.0       1851.0
# 10123                       NaN           NaN          NaN
# 10124                       NaN           NaN          NaN
# 10125                       NaN           NaN          NaN
# 10126                       NaN           NaN          NaN
#
#        Credit_Open_To_Buy  Total_Amount_Change_Q4_vs_Q1  \
# 0                     NaN                           NaN
# 1                  7392.0                         1.541
# 2                  3418.0                         2.594
# 3                     NaN                           NaN
# 4                     NaN                           NaN
# ...                   ...                           ...
# 10122              2152.0                         0.703
# 10123                 NaN                           NaN
# 10124                 NaN                           NaN
# 10125                 NaN                           NaN
# 10126                 NaN                           NaN
#
#        Total_Transitions_Amount  Total_Transitions_Count  \
# 0                           NaN                      NaN
# 1                        1291.0                     33.0
# 2                        1887.0                     20.0
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 10122                   15476.0                    117.0
# 10123                       NaN                      NaN
# 10124                       NaN                      NaN
# 10125                       NaN                      NaN
# 10126                       NaN                      NaN
#
#        Total_Count_Change_Q4_vs_Q1  Credit_Avg_Utilization_Ratio
# 0                              NaN                           NaN
# 1                            3.714                         0.105
# 2                            2.333                         0.000
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 10122                        0.857                         0.462
# 10123                          NaN                           NaN
# 10124                          NaN                           NaN
# 10125                          NaN                           NaN
# 10126                          NaN                           NaN
#
# [10127 rows x 21 columns]

# %% [markdown]
# # OPERATION #2

# %%
loyal = credit_card_customers[credit_card_customers.Attrition_Flag == "Existing Customer"]

# %%
churn = credit_card_customers[credit_card_customers.Attrition_Flag != "Existing Customer"]

# %%
x = loyal.Total_Count_Change_Q4_vs_Q1.mean()
filter_results_2 = churn[churn["Total_Count_Change_Q4_vs_Q1"] > x]
filter_results_2
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 51     779471883  Attrited Customer            54      F                1
# 140    789322833  Attrited Customer            48      F                5
# 144    767712558  Attrited Customer            59      M                1
# 276    719211558  Attrited Customer            45      M                2
# 286    720272958  Attrited Customer            48      M                2
# ...          ...                ...           ...    ...              ...
# 10105  709646433  Attrited Customer            59      F                1
# 10107  713924283  Attrited Customer            61      M                0
# 10113  713733633  Attrited Customer            27      M                0
# 10118  713755458  Attrited Customer            50      M                1
# 10124  716506083  Attrited Customer            44      F                1
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 51           Graduate        Married  Less than $40K          Blue
# 140       High School        Married  Less than $40K          Blue
# 144           College         Single     $60K - $80K          Blue
# 276          Graduate         Single     $60K - $80K          Blue
# 286       High School        Married         $120K +          Blue
# ...               ...            ...             ...           ...
# 10105     High School        Married  Less than $40K          Blue
# 10107        Graduate         Single     $60K - $80K          Blue
# 10113     High School       Divorced     $60K - $80K          Blue
# 10118         Unknown        Unknown    $80K - $120K          Blue
# 10124     High School        Married  Less than $40K          Blue
#
#        Months_on_book  ...  Months_Inactive_Count_Last_Year  \
# 51                 40  ...                                3
# 140                38  ...                                3
# 144                53  ...                                3
# 276                36  ...                                1
# 286                36  ...                                3
# ...               ...  ...                              ...
# 10105              50  ...                                4
# 10107              54  ...                                1
# 10113              36  ...                                3
# 10118              36  ...                                3
# 10124              36  ...                                3
#
#        Contacts_Count_Last_Year  Credit_Limit  Credit_Used  \
# 51                            1        1438.3          808
# 140                           3        8025.0            0
# 144                           3       14979.0            0
# 276                           2        3401.0            0
# 286                           3       27126.0            0
# ...                         ...           ...          ...
# 10105                         3        5043.0          743
# 10107                         4       11859.0         1644
# 10113                         2       13303.0         2517
# 10118                         4        9959.0          952
# 10124                         4        5409.0            0
#
#        Credit_Open_To_Buy  Total_Amount_Change_Q4_vs_Q1  \
# 51                  630.3                         0.997
# 140                8025.0                         0.654
# 144               14979.0                         0.710
# 276                3401.0                         0.898
# 286               27126.0                         0.953
# ...                   ...                           ...
# 10105              4300.0                         0.805
# 10107             10215.0                         0.866
# 10113             10786.0                         0.929
# 10118              9007.0                         0.825
# 10124              5409.0                         0.819
#
#        Total_Transitions_Amount  Total_Transitions_Count  \
# 51                          705                       19
# 140                         673                       18
# 144                         530                       10
# 276                         744                       18
# 286                        1000                       25
# ...                         ...                      ...
# 10105                     10170                       66
# 10107                      8930                       79
# 10113                     10219                       85
# 10118                     10310                       63
# 10124                     10291                       60
#
#        Total_Count_Change_Q4_vs_Q1  Credit_Avg_Utilization_Ratio
# 51                           0.900                         0.562
# 140                          0.800                         0.000
# 144                          1.000                         0.000
# 276                          1.000                         0.000
# 286                          0.786                         0.000
# ...                            ...                           ...
# 10105                        0.784                         0.147
# 10107                        0.837                         0.139
# 10113                        0.809                         0.189
# 10118                        1.100                         0.096
# 10124                        0.818                         0.000
#
# [308 rows x 21 columns]

# %%
figs = filter_results_2.explain(top_k=3, figs_in_row = 1)

# %% [markdown]
# # OPERATION #3

# %%
churn
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 21     708508758  Attrited Customer            62      F                0
# 39     708300483  Attrited Customer            66      F                0
# 51     779471883  Attrited Customer            54      F                1
# 54     714374133  Attrited Customer            56      M                2
# 61     712030833  Attrited Customer            48      M                2
# ...          ...                ...           ...    ...              ...
# 10119  716893683  Attrited Customer            55      F                3
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 21           Graduate        Married  Less than $40K          Blue
# 39          Doctorate        Married         Unknown          Blue
# 51           Graduate        Married  Less than $40K          Blue
# 54           Graduate        Married         $120K +          Blue
# 61           Graduate        Married     $60K - $80K        Silver
# ...               ...            ...             ...           ...
# 10119      Uneducated         Single         Unknown          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Months_Inactive_Count_Last_Year  \
# 21                 49  ...                                3
# 39                 56  ...                                4
# 51                 40  ...                                3
# 54                 36  ...                                3
# 61                 35  ...                                4
# ...               ...  ...                              ...
# 10119              47  ...                                3
# 10123              25  ...                                2
# 10124              36  ...                                3
# 10125              36  ...                                3
# 10126              25  ...                                2
#
#        Contacts_Count_Last_Year  Credit_Limit  Credit_Used  \
# 21                            3        1438.3            0
# 39                            3        7882.0          605
# 51                            1        1438.3          808
# 54                            3       15769.0            0
# 61                            4       34516.0            0
# ...                         ...           ...          ...
# 10119                         3       14657.0         2517
# 10123                         3        4277.0         2186
# 10124                         4        5409.0            0
# 10125                         3        5281.0            0
# 10126                         4       10388.0         1961
#
#        Credit_Open_To_Buy  Total_Amount_Change_Q4_vs_Q1  \
# 21                 1438.3                         1.047
# 39                 7277.0                         1.052
# 51                  630.3                         0.997
# 54                15769.0                         1.041
# 61                34516.0                         0.763
# ...                   ...                           ...
# 10119             12140.0                         0.166
# 10123              2091.0                         0.804
# 10124              5409.0                         0.819
# 10125              5281.0                         0.535
# 10126              8427.0                         0.703
#
#        Total_Transitions_Amount  Total_Transitions_Count  \
# 21                          692                       16
# 39                          704                       16
# 51                          705                       19
# 54                          602                       15
# 61                          691                       15
# ...                         ...                      ...
# 10119                      6009                       53
# 10123                      8764                       69
# 10124                     10291                       60
# 10125                      8395                       62
# 10126                     10294                       61
#
#        Total_Count_Change_Q4_vs_Q1  Credit_Avg_Utilization_Ratio
# 21                           0.600                         0.000
# 39                           0.143                         0.077
# 51                           0.900                         0.562
# 54                           0.364                         0.000
# 61                           0.500                         0.000
# ...                            ...                           ...
# 10119                        0.514                         0.172
# 10123                        0.683                         0.511
# 10124                        0.818                         0.000
# 10125                        0.722                         0.000
# 10126                        0.649                         0.189
#
# [1627 rows x 21 columns]

# %%
group_by_decade_result = churn.groupby('Marital_Status').agg(
    {"Credit_Limit":[ "mean", "max"], "Credit_Used": "mean"})

# %%
figures = group_by_decade_result.explain(top_k=2, use_sampling=False, figs_in_row = 1)

# %%
group_by_decade_result = churn.groupby(["Marital_Status", "Gender", "Education_Level"])['Credit_Used'].mean()

# %%
group_by_decade_result
# Out:
# Marital_Status  Gender  Education_Level
# Divorced        F       College             762.000000
#                         Doctorate          1148.600000
#                         Graduate            635.315789
#                         High School        1146.545455
#                         Post-Graduate      1163.750000
#                         Uneducated          669.875000
#                         Unknown             468.222222
#                 M       College             337.285714
#                         Doctorate           590.333333
#                         Graduate            241.764706
#                         High School        1262.636364
#                         Post-Graduate       199.500000
#                         Uneducated         1072.250000
#                         Unknown             828.428571
# Married         F       College             722.394737
#                         Doctorate           881.031250
#                         Graduate            742.038168
#                         High School         569.756410
#                         Post-Graduate       444.450000
#                         Uneducated          602.931818
#                         Unknown             462.101449
#                 M       College             837.515152
#                         Doctorate           913.857143
#                         Graduate            765.963415
#                         High School         523.813559
#                         Post-Graduate      1032.470588
#                         Uneducated          526.897959
#                         Unknown             684.372093
# Single          F       College             825.666667
#                         Doctorate           606.304348
#                         Graduate            552.218487
#                         High School         682.272727
#                         Post-Graduate       935.117647
#                         Uneducated          763.593220
#                         Unknown             643.044776
#                 M       College             386.636364
#                         Doctorate           494.333333
#                         Graduate            648.686747
#                         High School         670.653846
#                         Post-Graduate       586.333333
#                         Uneducated          894.534884
#                         Unknown             977.391304
# Unknown         F       College             952.571429
#                         Doctorate             0.000000
#                         Graduate            641.166667
#                         High School         695.117647
#                         Post-Graduate      1828.666667
#                         Uneducated          835.500000
#                         Unknown             552.000000
#                 M       College               0.000000
#                         Doctorate             0.000000
#                         Graduate            664.333333
#                         High School         316.333333
#                         Post-Graduate       669.222222
#                         Uneducated          575.571429
#                         Unknown             776.111111
# Name: Credit_Used_mean, dtype: float64

# %%
figs = group_by_decade_result.explain(top_k = 5, show_scores=True)

# %% [markdown]
# # OPERATION #4

# %%
from functools import reduce

def total_more_then_20(series):
    return reduce(lambda x, y: x + 1 if y > 0.2 else x, series, 0)

# %%
group_by_decade_result = churn.groupby(by=['Income_Category', 'Gender', 'Education_Level']).agg(
    {"Credit_Avg_Utilization_Ratio": ['mean', total_more_then_20]})
group_by_decade_result
# Out:
#                                        Credit_Avg_Utilization_Ratio  \
#                                                                mean
# Income_Category Gender Education_Level
# $120K +         M      College                             0.045333
#                        Doctorate                           0.049375
#                        Graduate                            0.052656
#                        High School                         0.076571
#                        Post-Graduate                       0.068250
#                        Uneducated                          0.087174
#                        Unknown                             0.057105
# $40K - $60K     F      College                             0.261333
#                        Doctorate                           0.230714
#                        Graduate                            0.130935
#                        High School                         0.188083
#                        Post-Graduate                       0.299444
#                        Uneducated                          0.268857
#                        Unknown                             0.183312
#                 M      College                             0.010333
#                        Doctorate                           0.000000
#                        Graduate                            0.116968
#                        High School                         0.090267
#                        Post-Graduate                       0.113750
#                        Uneducated                          0.237800
#                        Unknown                             0.215278
# $60K - $80K     M      College                             0.079118
#                        Doctorate                           0.164000
#                        Graduate                            0.070058
#                        High School                         0.072167
#                        Post-Graduate                       0.135250
#                        Uneducated                          0.109625
#                        Unknown                             0.074484
# $80K - $120K    M      College                             0.142194
#                        Doctorate                           0.156091
#                        Graduate                            0.100821
#                        High School                         0.070878
#                        Post-Graduate                       0.084824
#                        Uneducated                          0.131243
#                        Unknown                             0.127939
# Less than $40K  F      College                             0.263833
#                        Doctorate                           0.258024
#                        Graduate                            0.203380
#                        High School                         0.212570
#                        Post-Graduate                       0.227548
#                        Uneducated                          0.254776
#                        Unknown                             0.210337
#                 M      College                             0.000000
#                        Graduate                            0.436400
#                        High School                         0.221750
#                        Post-Graduate                       0.000000
#                        Uneducated                          0.239000
#                        Unknown                             0.213000
# Unknown         F      College                             0.137625
#                        Doctorate                           0.215133
#                        Graduate                            0.187362
#                        High School                         0.129256
#                        Post-Graduate                       0.262750
#                        Uneducated                          0.138433
#                        Unknown                             0.115593
#                 M      Doctorate                           0.000000
#                        Graduate                            0.000000
#                        Uneducated                          0.000000
#
#
#                                        total_more_then_20
# Income_Category Gender Education_Level
# $120K +         M      College                          1
#                        Doctorate                        1
#                        Graduate                         3
#                        High School                      4
#                        Post-Graduate                    0
#                        Uneducated                       4
#                        Unknown                          1
# $40K - $60K     F      College                          6
#                        Doctorate                        3
#                        Graduate                        13
#                        High School                     11
#                        Post-Graduate                    5
#                        Uneducated                      10
#                        Unknown                          9
#                 M      College                          0
#                        Doctorate                        0
#                        Graduate                         6
#                        High School                      3
#                        Post-Graduate                    3
#                        Uneducated                      10
#                        Unknown                          7
# $60K - $80K     M      College                          2
#                        Doctorate                        1
#                        Graduate                         7
#                        High School                      5
#                        Post-Graduate                    3
#                        Uneducated                       4
#                        Unknown                          5
# $80K - $120K    M      College                          7
#                        Doctorate                        3
#                        Graduate                        10
#                        High School                      4
#                        Post-Graduate                    2
#                        Uneducated                       7
#                        Unknown                          9
# Less than $40K  F      College                         20
#                        Doctorate                       17
#                        Graduate                        66
#                        High School                     33
#                        Post-Graduate                   11
#                        Uneducated                      28
#                        Unknown                         33
#                 M      College                          0
#                        Graduate                         7
#                        High School                      3
#                        Post-Graduate                    0
#                        Uneducated                       1
#                        Unknown                          1
# Unknown         F      College                          4
#                        Doctorate                        6
#                        Graduate                        14
#                        High School                     11
#                        Post-Graduate                    2
#                        Uneducated                       7
#                        Unknown                          4
#                 M      Doctorate                        0
#                        Graduate                         0
#                        Uneducated                       0

# %%
group_by_decade_result.explain(show_scores=True)
# Out:
# C:\Users\Yuval\PycharmProjects\FEDEx_Generator\src\fedex_generator\Measures\DiversityMeasure.py:304: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if value not in columns:
# C:\Users\Yuval\PycharmProjects\FEDEx_Generator\src\fedex_generator\Measures\BaseMeasure.py:508: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
