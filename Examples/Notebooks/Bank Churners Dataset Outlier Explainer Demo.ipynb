# %% [markdown]
# ## Initial

# %%
import pandas as pd
import pd_explain
import numpy as np

# %%
bank_all = (pd.read_csv(r"..\Datasets\bank_churners_user_study.csv"))

# %%
bank_all.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Registered_Products_Count  Months_Inactive_Count_Last_Year  \
# count               10127.000000                     10127.000000
# mean                    3.812580                         2.341167
# std                     1.554408                         1.010622
# min                     1.000000                         0.000000
# 25%                     3.000000                         2.000000
# 50%                     4.000000                         2.000000
# 75%                     5.000000                         3.000000
# max                     6.000000                         6.000000
#
#        Contacts_Count_Last_Year  Credit_Limit   Credit_Used  \
# count              10127.000000  10127.000000  10127.000000
# mean                   2.455317   8631.953698   1162.814061
# std                    1.106225   9088.776650    814.987335
# min                    0.000000   1438.300000      0.000000
# 25%                    2.000000   2555.000000    359.000000
# 50%                    2.000000   4549.000000   1276.000000
# 75%                    3.000000  11067.500000   1784.000000
# max                    6.000000  34516.000000   2517.000000
#
#        Credit_Open_To_Buy  Total_Amount_Change_Q4_vs_Q1  \
# count        10127.000000                  10127.000000
# mean          7469.139637                      0.759941
# std           9090.685324                      0.219207
# min              3.000000                      0.000000
# 25%           1324.500000                      0.631000
# 50%           3474.000000                      0.736000
# 75%           9859.000000                      0.859000
# max          34516.000000                      3.397000
#
#        Total_Transitions_Amount  Total_Transitions_Count  \
# count              10127.000000             10127.000000
# mean                4404.086304                64.858695
# std                 3397.129254                23.472570
# min                  510.000000                10.000000
# 25%                 2155.500000                45.000000
# 50%                 3899.000000                67.000000
# 75%                 4741.000000                81.000000
# max                18484.000000               139.000000
#
#        Total_Count_Change_Q4_vs_Q1  Credit_Avg_Utilization_Ratio
# count                 10127.000000                  10127.000000
# mean                      0.712222                      0.274894
# std                       0.238086                      0.275691
# min                       0.000000                      0.000000
# 25%                       0.582000                      0.023000
# 50%                       0.702000                      0.176000
# 75%                       0.818000                      0.503000
# max                       3.714000                      0.999000

# %% [markdown]
# ## example 1

# %%
by_category = bank_all.groupby(['Income_Category'])['CLIENTNUM'].count()

# %%
by_category.plot(kind='bar')
# Out:
# <Axes: xlabel='Income_Category'>

# %%
# ['Less than $40K']
by_category.explain(target='Less than $40K', explainer='outlier', dir='high')

# %%
females = bank_all[bank_all['Gender'] == 'F']
females['Income_Category'].value_counts()
# Out:
# Income_Category
# Less than $40K    3284
# Unknown           1060
# $40K - $60K       1014
# Name: count, dtype: int64

# %%
females_by_category = females.groupby(['Income_Category'])['CLIENTNUM'].count()

# %%
females_by_category.plot(kind='bar')
# Out:
# <Axes: xlabel='Income_Category'>

# %%
females_by_category.explain(target='Less than $40K', explainer='outlier', dir="high")

# %% [markdown]
# ## example 2

# %%
bank_all['Income_Category'].value_counts()
# Out:
# Income_Category
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: count, dtype: int64

# %%
younger = bank_all[bank_all['Customer_Age'] <= 60]

# %%
limit_by_age = younger.groupby(['Customer_Age']).Credit_Limit.mean()

# %%
limit_by_age.explain(use_sampling=True, sample_size=0.7)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 limit_by_age.explain(use_sampling=True, sample_size=0.7)
#
# File ~\PycharmProjects\pd-explain\src\pd_explain\core\explainable_series.py:284, in ExpSeries.explain(self, schema, attributes, use_sampling, sample_size, top_k, figs_in_row, explainer, target, dir, control, hold_out, show_scores, title, labels, coverage_threshold, max_explanation_length, separation_threshold, p_value, explanation_form, prune_if_too_many_labels, max_labels, pruning_method, bin_numeric, num_bins, binning_method, label_name, explain_errors, error_explanation_threshold)
#     267 factory = ExplainerFactory()
#     268 explainer = factory.create_explainer(
#     269     schema=schema, attributes=attributes, top_k=top_k, explainer=explainer,
#     270     target=target, dir=dir, control=control, hold_out=hold_out,
#    (...)
#     281     explain_errors=explain_errors, error_explanation_threshold=error_explanation_threshold
#     282 )
# --> 284 explanation = explainer.generate_explanation()
#     286 if explainer.can_visualize():
#     287     return explainer.visualize()
#
# File ~\PycharmProjects\pd-explain\src\pd_explain\explainers\fedex_explainer.py:85, in FedexExplainer.generate_explanation(self)
#      82     return self._results
#      84 else:
# ---> 85     self._results = self._operation.explain(
#      86         schema=self._schema, attributes=self._attributes, top_k=self._top_k,
#      87         figs_in_row=self._figs_in_row, show_scores=self._show_scores, title=self._title, corr_TH=self._corr_TH,
#      88         explainer=self._explainer, consider=self._consider, cont=self._value, attr=self._attr,
#      89         ignore=self._ignore, use_sampling=self._use_sampling, sample_size=self._sample_size
#      90     )
#      92 return self._results
#
# File ~\PycharmProjects\FEDEx_Generator\src\fedex_generator\Operations\GroupBy.py:101, in GroupBy.explain(self, schema, attributes, top_k, explainer, figs_in_row, show_scores, title, corr_TH, consider, cont, attr, ignore, use_sampling, sample_size)
#      99 # Unless the outlier explainer is used, the diversity measure is always used for the groupby operation.
#     100 measure = DiversityMeasure()
# --> 101 scores = measure.calc_measure(self, schema, attributes, ignore=ignore, unsampled_source_df=backup_source_df,
#     102                               unsampled_res_df=backup_res_df, column_mapping=self._column_mapping)
#     103 figures = measure.calc_influence(utils.max_key(scores), top_k=top_k, figs_in_row=figs_in_row,
#     104                                  show_scores=show_scores, title=title)
#     106 if use_sampling:
#
# File ~\PycharmProjects\FEDEx_Generator\src\fedex_generator\Measures\BaseMeasure.py:227, in BaseMeasure.calc_measure(self, operation_object, scheme, use_only_columns, ignore, unsampled_source_df, unsampled_res_df, column_mapping)
#     222 with ThreadPoolExecutor() as executor:
#     223     futures = [
#     224         executor.submit(self._calc_measure, attr, dataset_relation, operation_object, scheme, use_only_columns,
#     225                         ignore, unsampled_source_df, unsampled_res_df, column_mapping) for attr, dataset_relation in operation_object.iterate_attributes()
#     226     ]
# --> 227     for future in as_completed(futures):
#     228         attr, measure_score, source_name, bins, cols = future.result()
#     229         if measure_score != -1:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
bank_all['Months_Inactive_Count_Last_Year'].value_counts()
# Out:
# Months_Inactive_Count_Last_Year
# 3    3846
# 2    3282
# 1    2233
# 4     435
# 5     178
# 6     124
# 0      29
# Name: count, dtype: int64

# %%
limit_by_age.explain(explainer='outlier', target=26, dir="low")
# Out:
# 'There was no explanation.'
