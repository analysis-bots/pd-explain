# %% [markdown]
# # Many to one explainer - demo

# %% [markdown]
# This notebook demonstrates the many to one explainer on the adult dataset.\
# This explainer is used to explain the relationship between a series labels and the rest of the dataset.\
# These labels can be a column from the datasets, a list of labels (for example, cluster labels), or groupby groups.\
# The explainer will provide rule based explanations for the labels, based on the rest of the dataset.\
# Please check the documentation for the available parameters and options for the many to one explainer, as not all of them are demonstrated here.

# %%
import pandas as pd
import pd_explain
# Out:
# usetex-False

# %%
adults = pd.read_csv(r"../../Datasets/adult.csv")

# %% [markdown]
# # Simple example - using the many to one explainer on the entire dataset:

# %% [markdown]
# Using the many to one explainer on a column from the dataset that has a many to one relationship with other columns:

# %%
adults.explain(explainer='many_to_one', labels='label')
# Out:
#                                                                    Coverage  \
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                               0.75
#                 0 <= capital-gain <= 5095.5                             1.0
#                 0 <= capital-gain <= 5095.5 AND 1 <= education-...     0.75
#                 0 <= capital-gain <= 4243.5                            0.99
# >50K            No explanation found                                    NaN
#
#                                                                    Separation Error  \
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                                       0.15
#                 0 <= capital-gain <= 5095.5                                    0.21
#                 0 <= capital-gain <= 5095.5 AND 1 <= education-...             0.13
#                 0 <= capital-gain <= 4243.5                                     0.2
# >50K            No explanation found                                            NaN
#
#                                                                    Separation Error Origins
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                            100.00% from group >50K
#                 0 <= capital-gain <= 5095.5                         100.00% from group >50K
#                 0 <= capital-gain <= 5095.5 AND 1 <= education-...  100.00% from group >50K
#                 0 <= capital-gain <= 4243.5                         100.00% from group >50K
# >50K            No explanation found                                                    NaN

# %% [markdown]
# # Using the many to one explainer on a subset of the dataset:

# %% [markdown]
# Using the many to one explainer on subsets of the data, that only contain numerical / categorical columns:

# %%
adults_numeric_only = adults[['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']]
adults_numeric_only
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 48837   39  215419             13             0             0              36
# 48838   64  321403              9             0             0              40
# 48839   38  374983             13             0             0              50
# 48840   44   83891             13          5455             0              40
# 48841   35  182148             13             0             0              60
#
# [48842 rows x 6 columns]

# %% [markdown]
# Just like we could provide a column name (if it is a column in the dataset), we can also pass a pandas series as the labels parameter:

# %%
labels = adults['label']

# %%
adults_numeric_only.explain(explainer='many_to_one', labels=labels, coverage_threshold=0.8, separation_threshold=0.2)
# Out:
#                                             Coverage Separation Error  \
# Group / Cluster Explanation
# <=50K           0 <= capital-gain <= 4243.5     0.99              0.2
# >50K            No explanation found             NaN              NaN
#
#                                             Separation Error Origins
# Group / Cluster Explanation
# <=50K           0 <= capital-gain <= 4243.5  100.00% from group >50K
# >50K            No explanation found                             NaN

# %%
adults_categorical_only = adults[['workclass', 'education', 'marital-status', 'occupation', 'relationship']]
adults_categorical_only
# Out:
#               workclass  education      marital-status         occupation  \
# 0             State-gov  Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private    HS-grad            Divorced  Handlers-cleaners
# 3               Private       11th  Married-civ-spouse  Handlers-cleaners
# 4               Private  Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...        ...                 ...                ...
# 48837           Private  Bachelors            Divorced     Prof-specialty
# 48838                 ?    HS-grad             Widowed                  ?
# 48839           Private  Bachelors  Married-civ-spouse     Prof-specialty
# 48840           Private  Bachelors            Divorced       Adm-clerical
# 48841      Self-emp-inc  Bachelors  Married-civ-spouse    Exec-managerial
#
#          relationship
# 0       Not-in-family
# 1             Husband
# 2       Not-in-family
# 3             Husband
# 4                Wife
# ...               ...
# 48837   Not-in-family
# 48838  Other-relative
# 48839         Husband
# 48840       Own-child
# 48841         Husband
#
# [48842 rows x 5 columns]

# %%
adults_categorical_only.explain(explainer='many_to_one', labels=labels, coverage_threshold=0.8, separation_threshold=0.3)
# Out:
#                                                                    Coverage  \
# Group / Cluster Explanation
# <=50K           occupation != Prof-specialty AND occupation != ...     0.82
#                 occupation != Exec-managerial                          0.91
#                 occupation != Prof-specialty                           0.91
# >50K            No explanation found                                    NaN
#
#                                                                    Separation Error  \
# Group / Cluster Explanation
# <=50K           occupation != Prof-specialty AND occupation != ...             0.17
#                 occupation != Exec-managerial                                  0.21
#                 occupation != Prof-specialty                                   0.21
# >50K            No explanation found                                            NaN
#
#                                                                    Separation Error Origins
# Group / Cluster Explanation
# <=50K           occupation != Prof-specialty AND occupation != ...  100.00% from group >50K
#                 occupation != Exec-managerial                       100.00% from group >50K
#                 occupation != Prof-specialty                        100.00% from group >50K
# >50K            No explanation found                                                    NaN

# %% [markdown]
# We can also specify only specific columns to be used in the many to one explainer:

# %%
adults.explain(explainer='many_to_one', attributes=['age', 'education', 'marital-status', 'relationship'], labels='label', coverage_threshold=0.8, separation_threshold=0.5)
# Out:
#                                                                 Coverage  \
# Group / Cluster Explanation
# <=50K           education != Bachelors                              0.87
#                 education != Bachelors AND education != Masters     0.84
#                 education != Masters                                0.97
# >50K            No explanation found                                 NaN
#
#                                                                 Separation Error  \
# Group / Cluster Explanation
# <=50K           education != Bachelors                                      0.21
#                 education != Bachelors AND education != Masters             0.18
#                 education != Masters                                        0.22
# >50K            No explanation found                                         NaN
#
#                                                                 Separation Error Origins
# Group / Cluster Explanation
# <=50K           education != Bachelors                           100.00% from group >50K
#                 education != Bachelors AND education != Masters  100.00% from group >50K
#                 education != Masters                             100.00% from group >50K
# >50K            No explanation found                                                 NaN

# %% [markdown]
# # Using many to one explainer with clustering labels:

# %%
from sklearn.cluster import KMeans

# %%
adults_with_dummies = pd.get_dummies(adults)

# %%
cluster_labels = KMeans(n_clusters=3).fit_predict(adults_with_dummies)

# %%
adults.explain(explainer='many_to_one', labels=cluster_labels)
# Out:
#                                                                    Coverage  \
# Group / Cluster Explanation
# 0               149278.5 <= fnlwgt <= 1490400                           1.0
#                 149278.5 <= fnlwgt <= 1490400 AND 8.5 <= educat...     0.87
# 1               291277.5 <= fnlwgt <= 1490400                           1.0
# 2               13769 <= fnlwgt <= 149278.5                             1.0
#
#                                                                    Separation Error  \
# Group / Cluster Explanation
# 0               149278.5 <= fnlwgt <= 1490400                                  0.22
#                 149278.5 <= fnlwgt <= 1490400 AND 8.5 <= educat...             0.21
# 1               291277.5 <= fnlwgt <= 1490400                                   0.0
# 2               13769 <= fnlwgt <= 149278.5                                     0.0
#
#                                                                          Separation Error Origins
# Group / Cluster Explanation
# 0               149278.5 <= fnlwgt <= 1490400                                100.00% from group 1
#                 149278.5 <= fnlwgt <= 1490400 AND 8.5 <= educat...           100.00% from group 1
# 1               291277.5 <= fnlwgt <= 1490400                       Rule has no separation error.
# 2               13769 <= fnlwgt <= 149278.5                         Rule has no separation error.

# %% [markdown]
# # Using many to one explainer to explain groupby groups:

# %% [markdown]
# Many to one explainer can also be used to explain groupby groups. It can work with single or multiple attributes groupby:

# %%
single_attribute_groupby = adults.groupby('relationship').mean()
single_attribute_groupby
# Out:
#                       age         fnlwgt  education-num  capital-gain  \
# relationship
# Husband         43.906066  187193.324102      10.305133   1774.499797
# Not-in-family   38.421601  190352.245013      10.326870    783.963284
# Other-relative  33.420983  203524.602258       8.849270    234.989376
# Own-child       24.794090  193782.299697       9.494394    174.381480
# Unmarried       40.312195  191370.284878       9.631610    450.863805
# Wife            40.078507  180748.781639      10.488631   1658.779923
#
#                 capital-loss  hours-per-week
# relationship
# Husband           122.200649       44.166109
# Not-in-family      76.840817       40.529842
# Other-relative     49.920983       37.128154
# Own-child          41.276217       33.142461
# Unmarried          46.638634       39.172488
# Wife              116.033033       36.729730

# %% [markdown]
# To explain a groupby's groups, we can use the explainer on the groupby dataframe without specifying the labels parameter:

# %%
single_attribute_groupby.explain(explainer='many_to_one', coverage_threshold=0.8, separation_threshold=0.2)
# Out:
#                                                                    Coverage  \
# Group / Cluster Explanation
# Husband         marital-status == Married-civ-spouse AND sex ==...      1.0
#                 marital-status == Married-civ-spouse AND sex !=...      1.0
#                 marital-status == Married-civ-spouse                    1.0
# Wife            marital-status == Married-civ-spouse AND sex !=...     0.99
#                 marital-status == Married-civ-spouse AND sex ==...     0.99
# Not-in-family   No explanation found                                    NaN
# Other-relative  No explanation found                                    NaN
# Own-child       No explanation found                                    NaN
# Unmarried       No explanation found                                    NaN
#
#                                                                    Separation Error  \
# Group / Cluster Explanation
# Husband         marital-status == Married-civ-spouse AND sex ==...             0.01
#                 marital-status == Married-civ-spouse AND sex !=...             0.01
#                 marital-status == Married-civ-spouse                           0.11
# Wife            marital-status == Married-civ-spouse AND sex !=...             0.05
#                 marital-status == Married-civ-spouse AND sex ==...             0.05
# Not-in-family   No explanation found                                            NaN
# Other-relative  No explanation found                                            NaN
# Own-child       No explanation found                                            NaN
# Unmarried       No explanation found                                            NaN
#
#                                                                                              Separation Error Origins
# Group / Cluster Explanation
# Husband         marital-status == Married-civ-spouse AND sex ==...  50.00% from group Other-relative, 40.91% from ...
#                 marital-status == Married-civ-spouse AND sex !=...  50.00% from group Other-relative, 40.91% from ...
#                 marital-status == Married-civ-spouse                87.69% from group Wife, 6.92% from group Other...
# Wife            marital-status == Married-civ-spouse AND sex !=...  63.64% from group Other-relative, 36.36% from ...
#                 marital-status == Married-civ-spouse AND sex ==...  63.64% from group Other-relative, 36.36% from ...
# Not-in-family   No explanation found                                                                              NaN
# Other-relative  No explanation found                                                                              NaN
# Own-child       No explanation found                                                                              NaN
# Unmarried       No explanation found                                                                              NaN

# %%
multi_attribute_groupby = adults.groupby(['sex', 'label']).mean()
multi_attribute_groupby
# Out:
#                     age         fnlwgt  education-num  capital-gain  \
# sex    label
# Female <=50K  36.278999  185690.282604       9.824724    122.876586
#        >50K   42.219333  183989.519503      11.832109   4313.663652
# Male   <=50K  37.248548  192799.098671       9.454953    162.322673
#        >50K   44.641863  189269.827082      11.561908   3993.827586
#
#               capital-loss  hours-per-week
# sex    label
# Female <=50K     46.910976       35.875962
#        >50K     180.222725       40.678915
# Male   <=50K     58.746173       40.720702
#        >50K     195.902299       46.304396

# %%
multi_attribute_groupby.explain(explainer='many_to_one', coverage_threshold=0.8, separation_threshold=0.55)
# Out:
#                                                                        Coverage  \
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                    1.0
#                     0 <= capital-gain <= 5095.5                             1.0
#                     relationship != Wife AND 0 <= capital-gain <= 5...      1.0
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...     0.99
#                     relationship != Husband AND 0 <= capital-gain <...      1.0
#                     relationship != Husband                                 1.0
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...     0.85
# ('Female', '>50K')  No explanation found                                    NaN
#
#                                                                        Separation Error  \
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                           0.51
#                     0 <= capital-gain <= 5095.5                                    0.51
#                     relationship != Wife AND 0 <= capital-gain <= 5...             0.49
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...             0.49
#                     relationship != Husband AND 0 <= capital-gain <...              0.5
#                     relationship != Husband                                        0.51
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...             0.52
# ('Female', '>50K')  No explanation found                                            NaN
#
#                                                                                                  Separation Error Origins
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                55.36% from group ('Female', '<=50K'), 41.31% ...
#                     0 <= capital-gain <= 5095.5                         59.76% from group ('Female', '<=50K'), 33.80% ...
#                     relationship != Wife AND 0 <= capital-gain <= 5...  60.39% from group ('Female', '<=50K'), 36.91% ...
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...  84.54% from group ('Male', '<=50K'), 10.40% fr...
#                     relationship != Husband AND 0 <= capital-gain <...  83.72% from group ('Male', '<=50K'), 11.04% fr...
#                     relationship != Husband                             79.11% from group ('Male', '<=50K'), 13.27% fr...
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...               100.00% from group ('Male', '<=50K')
# ('Female', '>50K')  No explanation found                                                                              NaN

# %% [markdown]
# It is also possible to pass a list of labels to the many to one explainer.
# It will then treat that list as groupby groups and explain each group separately, as if a groupby was performed:

# %%
adults.explain(explainer='many_to_one', coverage_threshold=0.8, separation_threshold=0.55, labels=['sex', 'label'])
# Out:
#                                                                        Coverage  \
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                    1.0
#                     0 <= capital-gain <= 5095.5                             1.0
#                     relationship != Wife AND 0 <= capital-gain <= 5...      1.0
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...     0.99
#                     relationship != Husband AND 0 <= capital-gain <...      1.0
#                     relationship != Husband                                 1.0
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...     0.85
# ('Female', '>50K')  No explanation found                                    NaN
#
#                                                                        Separation Error  \
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                           0.51
#                     0 <= capital-gain <= 5095.5                                    0.51
#                     relationship != Wife AND 0 <= capital-gain <= 5...             0.49
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...             0.49
#                     relationship != Husband AND 0 <= capital-gain <...              0.5
#                     relationship != Husband                                        0.51
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...             0.52
# ('Female', '>50K')  No explanation found                                            NaN
#
#                                                                                                  Separation Error Origins
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                55.36% from group ('Female', '<=50K'), 41.31% ...
#                     0 <= capital-gain <= 5095.5                         59.76% from group ('Female', '<=50K'), 33.80% ...
#                     relationship != Wife AND 0 <= capital-gain <= 5...  60.39% from group ('Female', '<=50K'), 36.91% ...
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...  84.54% from group ('Male', '<=50K'), 10.40% fr...
#                     relationship != Husband AND 0 <= capital-gain <...  83.72% from group ('Male', '<=50K'), 11.04% fr...
#                     relationship != Husband                             79.11% from group ('Male', '<=50K'), 13.27% fr...
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...               100.00% from group ('Male', '<=50K')
# ('Female', '>50K')  No explanation found                                                                              NaN

# %% [markdown]
# Another option is to pass a dataframe with multiple columns as the labels parameter.\
# These columns will be aggregated into a single column, and treated like a groupby:

# %%
labels = adults[['sex', 'label']]
adults.drop(columns=['sex', 'label']).explain(explainer='many_to_one', labels=labels, coverage_threshold=0.8, separation_threshold=0.55)
# Out:
#                                                                        Coverage  \
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                    1.0
#                     0 <= capital-gain <= 5095.5                             1.0
#                     relationship != Wife AND 0 <= capital-gain <= 5...      1.0
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...     0.99
#                     relationship != Husband AND 0 <= capital-gain <...      1.0
#                     relationship != Husband                                 1.0
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...     0.85
# ('Female', '>50K')  No explanation found                                    NaN
#
#                                                                        Separation Error  \
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                           0.51
#                     0 <= capital-gain <= 5095.5                                    0.51
#                     relationship != Wife AND 0 <= capital-gain <= 5...             0.49
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...             0.49
#                     relationship != Husband AND 0 <= capital-gain <...              0.5
#                     relationship != Husband                                        0.51
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...             0.52
# ('Female', '>50K')  No explanation found                                            NaN
#
#                                                                                                  Separation Error Origins
# Group / Cluster     Explanation
# ('Male', '<=50K')   relationship != Wife                                55.36% from group ('Female', '<=50K'), 41.31% ...
#                     0 <= capital-gain <= 5095.5                         59.76% from group ('Female', '<=50K'), 33.80% ...
#                     relationship != Wife AND 0 <= capital-gain <= 5...  60.39% from group ('Female', '<=50K'), 36.91% ...
# ('Female', '<=50K') relationship != Husband AND 0 <= capital-gain <...  84.54% from group ('Male', '<=50K'), 10.40% fr...
#                     relationship != Husband AND 0 <= capital-gain <...  83.72% from group ('Male', '<=50K'), 11.04% fr...
#                     relationship != Husband                             79.11% from group ('Male', '<=50K'), 13.27% fr...
# ('Male', '>50K')    relationship == Husband AND 8.5 <= education-nu...               100.00% from group ('Male', '<=50K')
# ('Female', '>50K')  No explanation found                                                                              NaN

# %% [markdown]
# # Many to one explainer when there are many groups / clusters:

# %%
from sklearn.cluster import KMeans
adults_with_dummies = pd.get_dummies(adults)

# %%
many_clusters = KMeans(n_clusters=20).fit_predict(adults_with_dummies)

# %% [markdown]
# In the case there are many groups (by default - over 10), the explainer will automatically prune them, selecting the most common ones.\
# This behavior is toggled by the `prune_if_too_many_labels` parameter, which is set to True by default. The maximum number of labels to keep is controlled by the `max_labels` parameter, which is set to 10 by default.\
# There are several pruning methods you can choose from using the `pruning_method` parameter:
# 1. `largest` - keep the k largest clusters. This is the default method.
# 2. `smallest` - keep the k smallest clusters.
# 3. `random` - keep k random clusters.
# 4. `max_dist` - keep the k clusters with the largest distance between their centroids.
# 5. `min_dist` - like max_dist, but with the smallest distance.
# 6. `max_silhouette` - keep the k clusters with the highest silhouette score.
# 7. `min_silhouette` - like max_silhouette, but with the lowest silhouette score.

# %%
adults.explain(explainer='many_to_one', labels=many_clusters, prune_if_too_many_labels=True, max_labels=10, pruning_method='largest')
# Out:
# There are more than the specified max number of 10 unique labels, and the option `prune_if_too_many_labels` is set to True. Pruning the labels to the top 10 most common labels using method largest
#                                                         Coverage  \
# Group / Cluster Explanation
# 0               183823.5 <= fnlwgt <= 206559.0               1.0
# 2               93156.0 <= fnlwgt <= 115335.0                1.0
# 5               13769 <= fnlwgt <= 56555.5                   1.0
#                 13769.0 <= fnlwgt <= 60842.833333333336      1.0
# 9               115335.0 <= fnlwgt <= 137813.5               1.0
# 11              262336.5 <= fnlwgt <= 296212                 1.0
# 12              137813.5 <= fnlwgt <= 161472.5               1.0
# 16              161472.5 <= fnlwgt <= 183823.5               1.0
# 19              56555.5 <= fnlwgt <= 93156.0                 1.0
# 8               No explanation found                         NaN
# 17              No explanation found                         NaN
#
#                                                         Separation Error  \
# Group / Cluster Explanation
# 0               183823.5 <= fnlwgt <= 206559.0                       0.0
# 2               93156.0 <= fnlwgt <= 115335.0                        0.0
# 5               13769 <= fnlwgt <= 56555.5                           0.0
#                 13769.0 <= fnlwgt <= 60842.833333333336              0.0
# 9               115335.0 <= fnlwgt <= 137813.5                       0.0
# 11              262336.5 <= fnlwgt <= 296212                         0.0
# 12              137813.5 <= fnlwgt <= 161472.5                       0.0
# 16              161472.5 <= fnlwgt <= 183823.5                       0.0
# 19              56555.5 <= fnlwgt <= 93156.0                         0.0
# 8               No explanation found                                 NaN
# 17              No explanation found                                 NaN
#
#                                                               Separation Error Origins
# Group / Cluster Explanation
# 0               183823.5 <= fnlwgt <= 206559.0           Rule has no separation error.
# 2               93156.0 <= fnlwgt <= 115335.0            Rule has no separation error.
# 5               13769 <= fnlwgt <= 56555.5               Rule has no separation error.
#                 13769.0 <= fnlwgt <= 60842.833333333336  Rule has no separation error.
# 9               115335.0 <= fnlwgt <= 137813.5           Rule has no separation error.
# 11              262336.5 <= fnlwgt <= 296212             Rule has no separation error.
# 12              137813.5 <= fnlwgt <= 161472.5           Rule has no separation error.
# 16              161472.5 <= fnlwgt <= 183823.5           Rule has no separation error.
# 19              56555.5 <= fnlwgt <= 93156.0             Rule has no separation error.
# 8               No explanation found                                               NaN
# 17              No explanation found                                               NaN

# %% [markdown]
# # Disjunctive explanations:

# %% [markdown]
# The many-to-one explainer supports disjunctive explanation generation, as well as the conjunctive explanations shown above.
# To generate disjunctive explanations, set the explanation_form parameter to 'disj' or 'disjunction':

# %%
adults.explain(explainer='many_to_one', explanation_form='disj', labels='label', attributes=['workclass', 'education', 'marital-status', 'occupation', 'relationship'], use_sampling=False)
# Out:
#                                                                    Coverage  \
# Group / Cluster Explanation
# <=50K           occupation != Prof-specialty OR education != Ba...     0.96
#                 occupation != Prof-specialty                           0.91
# >50K            No explanation found                                    NaN
#
#                                                                    Separation Error  \
# Group / Cluster Explanation
# <=50K           occupation != Prof-specialty OR education != Ba...             0.23
#                 occupation != Prof-specialty                                   0.21
# >50K            No explanation found                                            NaN
#
#                                                                    Separation Error Origins
# Group / Cluster Explanation
# <=50K           occupation != Prof-specialty OR education != Ba...  100.00% from group >50K
#                 occupation != Prof-specialty                        100.00% from group >50K
# >50K            No explanation found                                                    NaN

# %% [markdown]
# # Additional features:

# %% [markdown]
# ### Automatic label dropping:

# %% [markdown]
# If the labels provided to the explainer contain NA values, the explainer will automatically drop those labels and the corresponding rows from the dataset:

# %%
labels = adults['label'].copy()
labels.iloc[:20] = None

# %%
adults.drop(columns=['label']).explain(explainer='many_to_one', labels=labels)
# Out:
# Dropping 20 labels with missing values.
#                                                                    Coverage  \
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                               0.76
#                 0 <= capital-gain <= 5095.5                             1.0
#                 0 <= capital-gain <= 5095.5 AND 1 <= education-...     0.76
#                 0 <= capital-gain <= 4243.5                            0.99
#                 0 <= capital-gain <= 4243.5 AND 1 <= education-...     0.75
# >50K            No explanation found                                    NaN
#
#                                                                    Separation Error  \
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                                       0.15
#                 0 <= capital-gain <= 5095.5                                    0.21
#                 0 <= capital-gain <= 5095.5 AND 1 <= education-...             0.13
#                 0 <= capital-gain <= 4243.5                                     0.2
#                 0 <= capital-gain <= 4243.5 AND 1 <= education-...             0.12
# >50K            No explanation found                                            NaN
#
#                                                                    Separation Error Origins
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                            100.00% from group >50K
#                 0 <= capital-gain <= 5095.5                         100.00% from group >50K
#                 0 <= capital-gain <= 5095.5 AND 1 <= education-...  100.00% from group >50K
#                 0 <= capital-gain <= 4243.5                         100.00% from group >50K
#                 0 <= capital-gain <= 4243.5 AND 1 <= education-...  100.00% from group >50K
# >50K            No explanation found                                                    NaN

# %% [markdown]
# ### Binning numeric labels:

# %% [markdown]
# If the labels provided are numeric, the explainer can automatically bin them using either the 'quantile' or 'uniform' strategies. This is controlled by the `bin_numeric` parameter, which is set to False by default.\
# The behavior of the binning can be controlled by the parameters `num_bins`, which is set to 10 by default, and `binning_method`, which is set to 'quantile' by default.\
# Binning will happen if the `bin_numeric` parameter is set to true, the labels are numeric, and the number of unique labels is greater than 10:

# %%
adults.explain(explainer='many_to_one', labels='education-num', bin_numeric=True)
# Out:
# Attribute 'education-num' in labels has more than specified number of 10 unique values. Binning the attribute.
#                                                          Coverage  \
# Group / Cluster              Explanation
# 11.0 < education-num <= 13.0 education == Bachelors          0.84
# 7.0 < education-num <= 9.0   education == HS-grad            0.96
# 9.0 < education-num <= 10.0  education == Some-college        1.0
# 10.0 < education-num <= 11.0 education == Assoc-voc           1.0
# 0.999 < education-num <= 7.0 No explanation found             NaN
# 13.0 < education-num <= 16.0 No explanation found             NaN
#
#                                                          Separation Error  \
# Group / Cluster              Explanation
# 11.0 < education-num <= 13.0 education == Bachelors                   0.0
# 7.0 < education-num <= 9.0   education == HS-grad                     0.0
# 9.0 < education-num <= 10.0  education == Some-college                0.0
# 10.0 < education-num <= 11.0 education == Assoc-voc                   0.0
# 0.999 < education-num <= 7.0 No explanation found                     NaN
# 13.0 < education-num <= 16.0 No explanation found                     NaN
#
#                                                                Separation Error Origins
# Group / Cluster              Explanation
# 11.0 < education-num <= 13.0 education == Bachelors       Rule has no separation error.
# 7.0 < education-num <= 9.0   education == HS-grad         Rule has no separation error.
# 9.0 < education-num <= 10.0  education == Some-college    Rule has no separation error.
# 10.0 < education-num <= 11.0 education == Assoc-voc       Rule has no separation error.
# 0.999 < education-num <= 7.0 No explanation found                                   NaN
# 13.0 < education-num <= 16.0 No explanation found                                   NaN

# %% [markdown]
# ### Sampling:

# %% [markdown]
# By default, the many to one explainer uses uniform random sampling to speed up explanation generation.\
# While the impact on explanation quality should, in most cases, be negligible, it is possible to turn off sampling by setting the `use_sampling` parameter to False.\
# You can also control the sample size using the `sample_size` parameter, which is set to 5000 by default.\
# This parameter can either be an integer, in which case it will be the exact sample size, or a float between 0 and 1, in which case it will be the percentage of the dataset size.\
# Please note that we do not allow the sample size to be below the default value of 5000, as this can lead to poor explanation quality for a very small gain in performance - you can only increase the sample size.

# %%
adults.explain(explainer='many_to_one', labels='label', use_sampling=False)
# Out:
#                                                                    Coverage  \
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                               0.76
#                 0.0 <= capital-gain <= 16666.5                          1.0
#                 0 <= capital-gain <= 4668.5 AND 1 <= education-...     0.75
#                 0 <= capital-gain <= 4668.5                            0.99
#                 0.0 <= capital-gain <= 19999.8                          1.0
#                 0 <= capital-gain <= 4243.5                            0.99
#                 0.0 <= capital-gain <= 24999.75                         1.0
#                 0 <= capital-gain <= 4243.5 AND 1 <= education-...     0.75
# >50K            No explanation found                                    NaN
#
#                                                                    Separation Error  \
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                                       0.15
#                 0.0 <= capital-gain <= 16666.5                                 0.23
#                 0 <= capital-gain <= 4668.5 AND 1 <= education-...             0.13
#                 0 <= capital-gain <= 4668.5                                     0.2
#                 0.0 <= capital-gain <= 19999.8                                 0.23
#                 0 <= capital-gain <= 4243.5                                     0.2
#                 0.0 <= capital-gain <= 24999.75                                0.23
#                 0 <= capital-gain <= 4243.5 AND 1 <= education-...             0.13
# >50K            No explanation found                                            NaN
#
#                                                                    Separation Error Origins
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                            100.00% from group >50K
#                 0.0 <= capital-gain <= 16666.5                      100.00% from group >50K
#                 0 <= capital-gain <= 4668.5 AND 1 <= education-...  100.00% from group >50K
#                 0 <= capital-gain <= 4668.5                         100.00% from group >50K
#                 0.0 <= capital-gain <= 19999.8                      100.00% from group >50K
#                 0 <= capital-gain <= 4243.5                         100.00% from group >50K
#                 0.0 <= capital-gain <= 24999.75                     100.00% from group >50K
#                 0 <= capital-gain <= 4243.5 AND 1 <= education-...  100.00% from group >50K
# >50K            No explanation found                                                    NaN

# %% [markdown]
# ### Explaining the separation error

# %% [markdown]
# The many to one explainer, by default, also provides an explanation for the separation error.\
# This explanation tells you how much of the separation error originates from each of the other groups, by percentage.\
# This can be disabled by setting the `explain_errors` parameter to False.

# %%
adults.explain(explainer='many_to_one', labels='label', explain_errors=False)
# Out:
#                                                                    Coverage  \
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                               0.75
#                 0 <= capital-gain <= 5095.5                             1.0
#                 0 <= capital-gain <= 5095.5 AND 1 <= education-...     0.75
#                 0 <= capital-gain <= 4243.5                            0.99
# >50K            No explanation found                                    NaN
#
#                                                                    Separation Error
# Group / Cluster Explanation
# <=50K           1 <= education-num <= 10                                       0.15
#                 0 <= capital-gain <= 5095.5                                    0.21
#                 0 <= capital-gain <= 5095.5 AND 1 <= education-...             0.13
#                 0 <= capital-gain <= 4243.5                                     0.2
# >50K            No explanation found                                            NaN

# %% [markdown]
# This behavior is also controlled by the `error_explanation_threshold` parameter, which is set to 0.05 by default. This parameter defines the minimum percentage a group must contribute to the separation error to be explained. If it contributes less, it will be aggregated along with other groups that do not meet the threshold, and explained as 'x% of the error originates from y other groups`.

# %%
single_attribute_groupby.explain(explainer='many_to_one', explanation_form='disj', error_explanation_threshold=0.01)
# Out:
#                                                      Coverage  \
# Group / Cluster Explanation
# Husband         marital-status == Married-civ-spouse      1.0
# Not-in-family   No explanation found                      NaN
# Other-relative  No explanation found                      NaN
# Own-child       No explanation found                      NaN
# Unmarried       No explanation found                      NaN
# Wife            No explanation found                      NaN
#
#                                                      Separation Error  \
# Group / Cluster Explanation
# Husband         marital-status == Married-civ-spouse             0.11
# Not-in-family   No explanation found                              NaN
# Other-relative  No explanation found                              NaN
# Own-child       No explanation found                              NaN
# Unmarried       No explanation found                              NaN
# Wife            No explanation found                              NaN
#
#                                                                                Separation Error Origins
# Group / Cluster Explanation
# Husband         marital-status == Married-civ-spouse  87.69% from group Wife, 6.92% from group Other...
# Not-in-family   No explanation found                                                                NaN
# Other-relative  No explanation found                                                                NaN
# Own-child       No explanation found                                                                NaN
# Unmarried       No explanation found                                                                NaN
# Wife            No explanation found                                                                NaN
