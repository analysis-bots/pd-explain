# %%
# %cd C:\Users\itaye\Desktop\pdexplain\pd-explain\src
# Out:
# C:\Users\itaye\Desktop\pdexplain\pd-explain\src
# C:\Users\itaye\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd
import pd_explain

# %%
spotify_all = (pd.read_csv(r"C:\Users\itaye\Desktop\pdexplain\pd-explain\Examples\Datasets\spotify_all.csv"))

# %%
popular_songs = spotify_all[spotify_all['popularity'] >= 90]
# popular_songs

# %%
inst_songs = spotify_all[spotify_all['speechiness'] <= 0.01]
inst_songs['popularity'].describe()
# Out:
# count    121.000000
# mean      23.520661
# std       28.433577
# min        0.000000
# 25%        0.000000
# 50%        5.000000
# 75%       57.000000
# max       84.000000
# Name: popularity, dtype: float64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
popular_non_speachy = spotify_all[spotify_all[]]

# %%
popular_artists = spotify_all[(spotify_all.popularity>80)][['main_artist','popularity']].drop_duplicates(subset=['main_artist']).set_index('main_artist')

# %%
popular_artists
# Out:
#                   popularity
# main_artist
# Bobby Helms               85
# Dean Martin               84
# Nat King Cole             81
# Andy Williams             85
# The Ronettes              82
# ...                      ...
# Kevin Roldan              81
# Christian Nodal           81
# Cali Y El Dandee          83
# Nea                       82
# Flow La Movie             81
#
# [246 rows x 1 columns]

# %%
pop_by_artist = spotify_all.groupby('main_artist').popularity.mean()

# %%
pop_by_artist.sort_values(key=lambda x: -x)[:10]
# Out:
# main_artist
# CJ               94.0
# Boza             92.0
# Manuel Turizo    91.0
# Joel Corry       91.0
# HVME             90.0
# Camilo           89.5
# Lele Pons        89.0
# Ritt Momney      89.0
# Justin Quiles    86.5
# Fousheé          86.0
# Name: popularity_mean, dtype: float64

# %%
pop_by_artist['Ariana Grande']
# Out:
# 70.93827160493827

# %%
spotify_all[spotify_all['main_artist'] == 'Ariana Grande'].instrumentalness.describe()
# Out:
# count    81.000000
# mean      0.000687
# std       0.006055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000002
# max       0.054500
# Name: instrumentalness, dtype: float64

# %%
spotify_all[spotify_all['main_artist'] == 'Drake'].instrumentalness.describe()
# Out:
# count    153.000000
# mean       0.005806
# std        0.039887
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000027
# max        0.391000
# Name: instrumentalness, dtype: float64

# %%
drake_instrumental = spotify_all[(spotify_all['main_artist'] == 'Drake') & (spotify_all['instrumentalness'] > 0.05)]
drake_instrumental
# Out:
#         acousticness                                   artists  danceability  \
# 19360        0.25600                                 ['Drake']         0.809
# 125965       0.09450  ['Drake', 'Black Coffee', 'Jorja Smith']         0.781
# 171812       0.00427         ['Drake', 'Peter Bjorn and John']         0.790
#
#         energy  explicit                      id  instrumentalness  key  \
# 19360    0.463         1  5mCPDVBb16L4XQwDdbRUpz             0.085   11
# 125965   0.721         1  7y6c07pgjZvtHI9kuMVqk1             0.391    5
# 171812   0.731         1  4FDSPGncHRpr6yB8DD4CtI             0.290    9
#
#         liveness  loudness  ...  \
# 19360      0.109   -11.377  ...
# 125965     0.104    -9.133  ...
# 171812     0.157    -4.607  ...
#
#                                                   name popularity  \
# 19360                                     Passionfruit         79
# 125965                                 Get It Together         68
# ...

# %%
ariana_instrumental = spotify_all[(spotify_all['main_artist'] == 'Ariana Grande') & (spotify_all['instrumentalness'] > 0.05)]
ariana_instrumental
# Out:
#        acousticness            artists  danceability  energy  explicit  \
# 93624        0.0268  ['Ariana Grande']         0.847   0.579         0
#
#                            id  instrumentalness  key  liveness  loudness  ...  \
# 93624  5Il6Oe7lr5XM7A0cWbVQtr            0.0545    1     0.102    -5.314  ...
#
#            name popularity  speechiness    tempo  valence  year  decade  \
# 93624  bad idea         72       0.0719  137.998    0.569  2019    2010
#
#        popularity_score    main_artist duration_minutes
# 93624                70  Ariana Grande         4.451783
#
# [1 rows x 21 columns]

# %%
count_artist = spotify_all.groupby('main_artist').main_artist.count()
count_artist = count_artist[count_artist.values > 100]
# count_artist.sort_values()
spotify_frequent = spotify_all[spotify_all['main_artist'].isin(count_artist.index)]
spotify_frequent
# Out:
#         acousticness               artists  danceability  energy  explicit  \
# 8             0.9960  ['Francisco Canaro']         0.469   0.238         0
# 11            0.9960  ['Francisco Canaro']         0.579   0.356         0
# 17            0.9960  ['Francisco Canaro']         0.468   0.533         0
# 63            0.9960  ['Francisco Canaro']         0.369   0.285         0
# 93            0.9960  ['Francisco Canaro']         0.433   0.322         0
# ...              ...                   ...           ...     ...       ...
# 174303        0.0216          ['Don Omar']         0.800   0.849         0
# 174305        0.2170          ['Don Omar']         0.741   0.787         0
# 174307        0.1070          ['Don Omar']         0.886   0.708         0
# 174309        0.2170          ['Don Omar']         0.741   0.787         0
# 174387        0.9200      ['Taylor Swift']         0.462   0.240         1
#
# ...

# %%
pop_by_artist = spotify_frequent.groupby('main_artist').popularity.mean()

# %%
pop_by_artist.sort_values(key=lambda x: -x)[:10]
# Out:
# main_artist
# Drake              62.026144
# Kanye West         61.550847
# Taylor Swift       61.168889
# Eminem             58.670455
# Luis Miguel        52.235849
# 2Pac               49.597315
# JAY-Z              48.462810
# AC/DC              48.413793
# Michael Jackson    48.133721
# Joan Sebastian     47.928571
# Name: popularity_mean, dtype: float64

# %% [markdown]
# Are there any that are both popular and have acoustic songs?

# %%
drake_instrumental = spotify_all[(spotify_all['main_artist'] == 'Taylor Swift') & (spotify_all['acousticness'] > 0.9)]
drake_instrumental
# Out:
#         acousticness                       artists  danceability  energy  \
# 19922          0.920              ['Taylor Swift']         0.462   0.240
# 20126          0.966              ['Taylor Swift']         0.661   0.180
# 20128          0.921              ['Taylor Swift']         0.462   0.242
# 39328          0.937  ['Taylor Swift', 'Bon Iver']         0.390   0.270
# 126617         0.918              ['Taylor Swift']         0.647   0.272
# 158571         0.920              ['Taylor Swift']         0.463   0.248
# 158613         0.966              ['Taylor Swift']         0.662   0.181
# 174387         0.920              ['Taylor Swift']         0.462   0.240
#
#         explicit                      id  instrumentalness  key  liveness  \
# 19922          1  0sY6ZUTh4yoctD8VIXz339          0.000000    0    0.1130
# 20126          0  20TF5vsgFrrrQCrJ4j6LRG          0.000003    8    0.1330
# 20128          1  2EliNOReCRCe1ynR6G8yeT          0.000000    0    0.1130
# ...
