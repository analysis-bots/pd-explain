# %%
import sys
import os
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import pd_explain
# Out:
# usetex-False

# %%
houses = pd.read_csv(r"..\Examples\Datasets\houses.csv")
houses
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
houses['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
expensive_houses = houses[houses['SalePrice'] > 214000]
expensive_houses.explain(top_k=3)

# %%
houses.groupby('YrSold').mean().explain(top_k=3)
# Out:
# max_value_numeric 1 - np.mean(res_col)180559.84544524192 / sqr3339.911025067717
# max_value_numeric 183252.19727411767 - np.mean(res_col)179459.18413915354 / sqr2248.6125674569557
# max_value_numeric 184657.67462490077 - np.mean(res_col)179989.6680131846 / sqr2867.355531799339
# max_value_numeric 1 - np.mean(res_col)10491.145452762616 / sqr228.056517144001
# max_value_numeric 10642.887386018238 - np.mean(res_col)10416.637157296902 / sqr155.56205445157462
# max_value_numeric 10753.28715805471 - np.mean(res_col)10446.575423806105 / sqr194.42959561667246
# max_value_numeric 1 - np.mean(res_col)563.407514161732 / sqr41.483445643875065
# max_value_numeric 514.0394736842105 - np.mean(res_col)548.8105975411911 / sqr24.05933025359472
# max_value_numeric 608.8620099510193 - np.mean(res_col)554.5773499377307 / sqr32.625205851766246

# %%
houses_relevant = houses[houses['YrSold'] == 2006]  
houses_relevant.explain()
