# %% [markdown]
# <span style="font-size:5em;"><strong>EDA Notebook: Spotify Songs Dataset</strong></span>
#
# see https://www.kaggle.com/c/bfh-spotify-challenge/data?select=test.csv
#
# In this session, we explore the Spotify songs dataset. We are interested in learning about interesting patterns, and what makes a song more likely to be popular.

# %% [markdown]
# # Technical setting

# %%
# !pip install pd-explain

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <span style="font-size:1.5em;"><strong>Typical EDA Workflow</strong></span>

# %% [markdown]
# importing the Pandas and PD-Explain libraries:

# %%
import pandas as pd
import pd_explain

# %% [markdown]
# the Spotify songs dataset contains songs from spotify, with various attributes such popularity of the song(between 0-100), main artist of the song, weather it contains explicit lyrics or not, it's year of release etc.
#
# Loading the dataset to a pandas DataFrame using the read_csv() method:

# %%
songs_df = pd.read_csv(r"..\Examples\Datasets\spotify_all.csv")
songs_df
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         energy  explicit                      id  instrumentalness  key  \
# 0        0.224         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5
# 1        0.517         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5
# 2        0.186         0  11m7laMUgmOKqI3oYzuhne          0.000018    0
# 3        0.798         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2
# 4        0.707         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10
# ...        ...       ...                     ...               ...  ...
# 174384   0.866         0  46LhBf6TvYjZU2SMvGZAbn          0.000060    6
# 174385   0.211         0  7tue2Wemjd0FZzRtDrQFZd          0.000000    4
# 174386   0.589         0  48Qj61hOdYmUCFJbpQ29Ob          0.920000    4
# 174387   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP          0.000000    0
# 174388   0.460         0  57tgYkWQTNHVFEt6xDKKZj          0.891000    7
#
#         liveness  loudness  ...  \
# 0         0.3790   -12.628  ...
# 1         0.0809    -7.261  ...
# 2         0.5190   -12.098  ...
# 3         0.1280    -7.311  ...
# 4         0.4020    -6.036  ...
# ...          ...       ...  ...
# 174384    0.1780    -5.089  ...
# 174385    0.1960   -11.665  ...
# 174386    0.1130   -12.393  ...
# 174387    0.1130   -12.077  ...
# 174388    0.2150   -12.237  ...
#
#                                                      name popularity  \
# 0                                Keep A Song In Your Soul         12
# 1                                    I Put A Spell On You          7
# 2                                            Golfing Papa          4
# 3       True House Music - Xavier Santos & Carlos Gomi...         17
# 4                                               Xuniverxe          2
# ...                                                   ...        ...
# 174384                                            The One          0
# 174385                                      A Little More          0
# 174386                                           Together          0
# 174387                                 champagne problems         69
# 174388                                     Improvisations          0
#
#         speechiness    tempo  valence  year  decade  popularity_score  \
# 0            0.0936  149.976   0.6340  1920    1920                10
# 1            0.0534   86.889   0.9500  1920    1920                 0
# 2            0.1740   97.600   0.6890  1920    1920                 0
# 3            0.0425  127.997   0.0422  1920    1920                10
# 4            0.0768  122.076   0.2990  1920    1920                 0
# ...             ...      ...      ...   ...     ...               ...
# 174384       0.0356  125.972   0.1860  2020    2020                 0
# 174385       0.0360   94.710   0.2280  2021    2020                 0
# 174386       0.0282  108.058   0.7140  2020    2020                 0
# 174387       0.0377  171.319   0.3200  2021    2020                60
# 174388       0.0258  112.208   0.7470  2020    2020                 0
#
#                   main_artist duration_minutes
# 0                 Mamie Smith         2.805550
# 1       Screamin' Jay Hawkins         2.503333
# 2                 Mamie Smith         2.730450
# 3             Oscar Velazquez         7.034783
# 4                        Mixe         2.753733
# ...                       ...              ...
# 174384               DJ Combo         2.460250
# 174385           Alessia Cara         2.412000
# 174386              Roger Fly         3.635783
# 174387           Taylor Swift         4.066667
# 174388              Roger Fly         3.295167
#
# [174389 rows x 21 columns]

# %% [markdown]
# Applying a filter operation, to only select popular songs-  with popularity greater than 65:

# %%
popular_songs_df = songs_df[songs_df['popularity'] > 65]

# %% [markdown]
# <span style="font-size:1em;"><strong>It's hard to make sense of this result:</strong></span>

# %%
popular_songs_df
# Out:
#         acousticness                                            artists  \
# 4262         0.67300  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 4662         0.97000                                   ['Judy Garland']
# 5262         0.79900                                     ['Gene Autry']
# 5662         0.92600             ['Bing Crosby', 'The Andrews Sisters']
# 5663         0.99400               ['Erik Satie', 'Philippe Entremont']
# ...              ...                                                ...
# 174183       0.02050                             ['RAYE', 'Rudimental']
# 174185       0.26300                                         ['Jasiah']
# 174187       0.01360                                  ['Playboi Carti']
# 174351       0.00984                                   ['Foo Fighters']
# 174387       0.92000                                   ['Taylor Swift']
#
#         danceability  energy  explicit                      id  \
# 4262           0.317  0.1580         0  4so0Wek9Ig1p6CRCHuINwW
# 4662           0.156  0.1840         0  030mot3ZKR3oskfMsqDB2R
# 5262           0.834  0.3710         0  25leEEaz1gIpp7o21Fqyjo
# 5662           0.641  0.4130         0  0cAhE2iDJApegDnVRx6fCK
# 5663           0.469  0.0128         0  5NGtFXVpXSvwunEIGeviY3
# ...              ...     ...       ...                     ...
# 174183         0.749  0.8200         0  3DTqHfTGj1c6y2gDXsTez4
# 174185         0.760  0.7940         1  0IGxkEgMeF1dwOSIj2IUrT
# 174187         0.876  0.4920         1  5UusfWUMMLEXLMc1ViNZoe
# 174351         0.530  0.7590         0  3NUmUIyzNLBp8bCFMH8Mif
# 174387         0.462  0.2400         1  1gcyHQpBQ1lfXGdhZmWrHP
#
#         instrumentalness  key  liveness  loudness  ...  \
# 4262            0.353000    9    0.3380   -16.485  ...
# 4662            0.004580    6    0.2600   -14.820  ...
# 5262            0.000000    1    0.2750   -11.990  ...
# 5662            0.000000    3    0.1910    -5.624  ...
# 5663            0.937000    7    0.0941   -36.856  ...
# ...                  ...  ...       ...       ...  ...
# 174183          0.000685    7    0.0775    -6.114  ...
# 174185          0.003240   10    0.0996    -4.311  ...
# 174187          0.000283   11    0.0678    -8.110  ...
# 174351          0.000000    7    0.3190    -7.067  ...
# 174387          0.000000    0    0.1130   -12.077  ...
#
#                                                      name popularity  \
# 4262                                      White Christmas         80
# 4662               Have Yourself A Merry Little Christmas         74
# 5262    Here Comes Santa Claus (Right Down Santa Claus...         73
# 5662                             Twelve Days Of Christmas         68
# 5663                                     Gymnopédie No. 1         68
# ...                                                   ...        ...
# 174183                                         Regardless         76
# 174185                                             Crisis         68
# 174187                                              @ MEH         70
# 174351                                   Waiting On A War         69
# 174387                                 champagne problems         69
#
#         speechiness    tempo  valence  year  decade  popularity_score  \
# 4262         0.0381  130.503    0.247  1942    1940                80
# 4662         0.0393  180.887    0.107  1944    1940                70
# 5262         0.0358   96.628    0.976  1947    1940                70
# 5662         0.0435  143.522    0.834  1949    1940                60
# 5663         0.1190   72.765    0.354  1949    1940                60
# ...             ...      ...      ...   ...     ...               ...
# 174183       0.0478  120.066    0.534  2020    2020                70
# 174185       0.3440  165.990    0.583  2020    2020                60
# 174187       0.1530  151.044    0.400  2020    2020                70
# 174351       0.0351  131.999    0.502  2021    2020                60
# 174387       0.0377  171.319    0.320  2021    2020                60
#
#           main_artist duration_minutes
# 4262      Bing Crosby         2.958000
# 4662     Judy Garland         2.705550
# 5262       Gene Autry         2.504450
# 5662      Bing Crosby         3.395767
# 5663       Erik Satie         3.431117
# ...               ...              ...
# 174183           RAYE         3.292883
# 174185         Jasiah         1.826583
# 174187  Playboi Carti         2.779983
# 174351   Foo Fighters         4.230667
# 174387   Taylor Swift         4.066667
#
# [7071 rows x 21 columns]

# %% [markdown]
# Applying another filter operation to select newer songs:

# %%
new_songs_df = songs_df[songs_df['year'] >= 1990]

# %% [markdown]
# Selecting the mean popularity of each decade:

# %%
gb_decade = new_songs_df.groupby('decade')['popularity'].mean()
gb_decade
# Out:
# decade
# 1990    43.120769
# 2000    43.167320
# 2010    29.579203
# 2020    19.171014
# Name: popularity_mean, dtype: float64

# %% [markdown]
# <span style="font-size:1em;"><strong>The mean popularity of the 2020s is lower than expected, and might be an outlier. Why?</strong></span>

# %% [markdown]
# ## tuple contribution

# %% [markdown]
# Data Engineering- adding a column that states if the artist "Metro Boomin" contributed to the creation of the song:

# %%
artist = 'Metro Boomin'
def is_by_artist(row):
    list = [a[1:-1] for a in row['artists'][1:-1].split(', ')]
    return True if artist in list else False
songs_df[f'Is By {artist}'] = songs_df.apply(is_by_artist, axis=1)
songs_df[f'Is By {artist}'].value_counts()
# Out:
# Is By Metro Boomin
# False    174367
# True         22
# Name: count, dtype: int64

# %% [markdown]
# Applying a filter to only select main artist of songs that were also made by "Metro Boomin" (notice how "Metro Boomin" himself is in that list):

# %%
artist_collaborators = songs_df[songs_df[f'Is By {artist}'] == True][['main_artist']].drop_duplicates().reset_index(drop=True)
artist_collaborators
# Out:
#     main_artist
# 0     21 Savage
# 1        Offset
# 2  Metro Boomin
# 3           NAV
# 4      Big Sean
# 5   James Blake

# %% [markdown]
# To measure which artist is responsible for Metro Boomin's success (in terms of popularity), we join "artist_collaborators" with the songs where Metro Boomin have participated.

# %%
artist_songs_collabs = artist_collaborators.join(songs_df[songs_df[f'Is By {artist}'] == True], on='main_artist', how='inner')
artist_songs_collabs
# Out:
#     index   main_artist  acousticness  \
# 0       0     21 Savage      0.373000
# 1       0     21 Savage      0.007480
# 2       0     21 Savage      0.231000
# 3       0     21 Savage      0.136000
# 4       0     21 Savage      0.331000
# 5       0     21 Savage      0.349000
# 6       0     21 Savage      0.005740
# 7       0     21 Savage      0.000647
# 8       0     21 Savage      0.005250
# 9       0     21 Savage      0.001630
# 10      0     21 Savage      0.097400
# 11      1        Offset      0.149000
# 12      2  Metro Boomin      0.368000
# 13      2  Metro Boomin      0.588000
# 14      2  Metro Boomin      0.733000
# 15      2  Metro Boomin      0.191000
# 16      2  Metro Boomin      0.070900
# 17      2  Metro Boomin      0.413000
# 18      3           NAV      0.483000
# 19      3           NAV      0.091900
# 20      4      Big Sean      0.014400
# 21      5   James Blake      0.403000
#
#                                               artists  danceability  energy  \
# 0             ['21 Savage', 'Metro Boomin', 'Future']         0.835   0.413
# 1                       ['21 Savage', 'Metro Boomin']         0.819   0.626
# 2              ['21 Savage', 'Metro Boomin', 'Drake']         0.647   0.667
# 3                       ['21 Savage', 'Metro Boomin']         0.906   0.444
# 4   ['21 Savage', 'Offset', 'Metro Boomin', 'Travi...         0.782   0.436
# 5         ['21 Savage', 'Metro Boomin', 'Young Thug']         0.825   0.733
# 6                       ['21 Savage', 'Metro Boomin']         0.847   0.733
# 7                       ['21 Savage', 'Metro Boomin']         0.635   0.793
# 8    ['21 Savage', 'Offset', 'Metro Boomin', 'Quavo']         0.845   0.399
# 9                       ['21 Savage', 'Metro Boomin']         0.774   0.706
# 10                      ['21 Savage', 'Metro Boomin']         0.862   0.274
# 11                         ['Offset', 'Metro Boomin']         0.880   0.428
# 12                          ['Metro Boomin', 'Gunna']         0.901   0.464
# 13                      ['Metro Boomin', '21 Savage']         0.810   0.353
# 14                   ['Metro Boomin', 'Travis Scott']         0.638   0.400
# 15       ['Metro Boomin', 'Swae Lee', 'Travis Scott']         0.675   0.230
# 16                ['Metro Boomin', 'Offset', 'Drake']         0.914   0.572
# 17  ['Metro Boomin', 'Travis Scott', 'Kodak Black'...         0.636   0.501
# 18                            ['NAV', 'Metro Boomin']         0.826   0.422
# 19  ['NAV', 'Metro Boomin', 'Playboi Carti', 'Offs...         0.680   0.549
# 20          ['Big Sean', 'Metro Boomin', 'Kash Doll']         0.619   0.404
# 21    ['James Blake', 'Travis Scott', 'Metro Boomin']         0.754   0.370
#
#     explicit                      id  instrumentalness  key  ...  \
# 0          1  6fwdbPMwP1zVStm8FybmkO          0.001330    1  ...
# 1          1  5SWnsxjhdcEDc7LJjq9UHk          0.101000   10  ...
# 2          1  4Q34FP1AT7GEl9oLgNtiWj          0.000000    5  ...
# 3          1  4gmmRb6bZJffOOiww1JGTO          0.000064    4  ...
# 4          1  5u6vkDnOyaf8LsteDAj2ub          0.000013    2  ...
# 5          1  3ruoIF2UnoXdzK8mR61ebq          0.000000    1  ...
# 6          1  6pcywuOeGGWeOQzdUyti6k          0.000010   10  ...
# 7          1  3CDVMejYHnB1SkEEx0T1N4          0.747000   10  ...
# 8          1  0tdCy39PgWN8LFWu34ORn3          0.740000    1  ...
# 9          1  7fxSLnklnayJNBIKntXedZ          0.000001    2  ...
# 10         1  2D2w9943rsnJOGCrI4aMQp          0.185000    0  ...
# 11         1  7sO5G9EABYOXQKNPNiE9NR          0.000051    9  ...
# 12         1  1fewSx2d5KIZ04wsooEBOz          0.000017    5  ...
# 13         1  0AluA5RNsa4Cx6XRhf2hWZ          0.000000    6  ...
# 14         1  6LyAwkJsHlW7RQ8S1cYAtM          0.000133   11  ...
# 15         1  22ykS8KWpd2r4zcRZ0XMK5          0.000000    1  ...
# 16         1  156LzfvMNKuXuiot4uzhGD          0.002370    2  ...
# 17         1  42k9e2hgl98IdgkXLg4pxs          0.000000   11  ...
# 18         1  0jiW3PNiHJxOhWh9oPBJ7m          0.000000    3  ...
# 19         1  3JWh19WsndEFg0UFRFeTiU          0.000071    5  ...
# 20         1  0fWBFDRTIuk8ZgNdZqhCer          0.000000    8  ...
# 21         0  4cQrSREMqBSvJ8ZzBZjVb8          0.000062    6  ...
#
#                                                  name  popularity  \
# 0                                    X (feat. Future)          72
# 1                                              Runnin          84
# 2                         Mr. Right Now (feat. Drake)          82
# 3                                            No Heart          71
# 4                                   Ghostface Killers          71
# 5                  Rich Nigga Shit (feat. Young Thug)          76
# 6                                     Glock In My Lap          75
# 7                                            Many Men          72
# 8                                        Rap Saved Me          65
# 9                                              Slidin          70
# 10                              My Choppa Hate Niggas          63
# 11                    Ric Flair Drip (& Metro Boomin)          81
# 12                          Space Cadet (feat. Gunna)          81
# 13                   10 Freaky Girls (with 21 Savage)          79
# 14                        Overdue (with Travis Scott)          70
# 15       Dreamcatcher (feat. Swae Lee & Travis Scott)          67
# 16       No Complaints (feat. Offset & Drake) (Bonus)          66
# 17  No More (feat. Travis Scott, Kodak Black & 21 ...          64
# 18                                       Held Me Down          63
# 19                                             Minute          61
# 20                           So Good (& Metro Boomin)          64
# 21      Mile High (feat. Travis Scott & Metro Boomin)          68
#
#     speechiness    tempo  valence  year  decade  popularity_score  \
# 0        0.3960  149.004   0.1110  2016    2010                70
# 1        0.2020  143.010   0.4150  2020    2020                80
# 2        0.3040  172.080   0.7040  2020    2020                80
# 3        0.3840  140.063   0.6780  2016    2010                70
# 4        0.1550   82.994   0.2430  2017    2010                70
# 5        0.0969   97.974   0.6200  2020    2020                70
# 6        0.1600  130.029   0.2020  2020    2020                70
# 7        0.0322   77.594   0.2810  2020    2020                70
# 8        0.3090  143.049   0.1480  2017    2010                60
# 9        0.3550  152.891   0.3820  2020    2020                70
# 10       0.4840   77.493   0.1460  2017    2010                60
# 11       0.2060  100.007   0.3330  2017    2010                80
# 12       0.0645  109.004   0.6380  2018    2010                80
# 13       0.3100   88.031   0.0727  2018    2010                70
# 14       0.0425  150.133   0.4950  2018    2010                70
# 15       0.2040  173.962   0.1010  2018    2010                60
# 16       0.1660  123.963   0.2030  2018    2010                60
# 17       0.3290   82.309   0.1960  2018    2010                60
# 18       0.1100  119.997   0.2230  2017    2010                60
# 19       0.2440  162.874   0.2900  2017    2010                60
# 20       0.4410   90.008   0.5660  2017    2010                60
# 21       0.1200  114.941   0.2280  2019    2010                60
#
#     duration_minutes  Is By Metro Boomin
# 0           4.314667                True
# 1           3.265100                True
# 2           3.230650                True
# 3           3.917333                True
# 4           4.482217                True
# 5           3.172183                True
# 6           3.226517                True
# 7           3.364267                True
# 8           4.293333                True
# 9           3.083950                True
# 10          2.477333                True
# 11          2.880000                True
# 12          3.387783                True
# 13          3.471550                True
# 14          2.768217                True
# 15          3.532000                True
# 16          4.424667                True
# 17          4.418667                True
# 18          3.801783                True
# 19          4.422883                True
# 20          4.478667                True
# 21          3.226667                True
#
# [22 rows x 23 columns]

# %% [markdown]
# Not we check which artist was most significantly responsible for Metro Boomin's success.
# 1. The most popular collaboration is when featuring on Offset songs:

# %%
artist_songs_collabs.groupby('main_artist').popularity.mean()
# Out:
# main_artist
# 21 Savage       72.818182
# Big Sean        64.000000
# James Blake     68.000000
# Metro Boomin    71.166667
# NAV             62.000000
# Offset          81.000000
# Name: popularity_mean, dtype: float64

# %% [markdown]
# 2. The most frequent collaboration is when featuring on 21 Savage songs:

# %%
artist_songs_collabs.groupby('main_artist').popularity.count()
# Out:
# main_artist
# 21 Savage       11
# Big Sean         1
# James Blake      1
# Metro Boomin     6
# NAV              2
# Offset           1
# Name: popularity_count, dtype: int64

# %% [markdown]
# <span style="font-size:1em;"><strong>On one hand, collaboration with Offset seems to be the obvious reason for Metro Boomin's success, since it resulted with the most popular result.</strong></span>
#
# <span style="font-size:1em;"><strong>On the other hand, The most frequent collaboration was with 21 Savage, and maybe yielded more popular songs?</strong></span>

# %% [markdown]
# #  <span style="font-size:1.5em;"><strong>PD-Explain- Explaining The Queries</strong></span>

# %% [markdown]
# Calling the PD-Explain explain() function, to get explanations for the first filter step:

# %%
popular_songs_df.explain(top_k = 3, figs_in_row = 3)

# %% [markdown]
# Calling the outlier explainer, to get an explanation for the outlier:

# %%
gb_decade.explain(explainer='outlier', target=2020, dir='low')

# %%
artist_songs_collabs.explain(explainer='shapley', value='mean', attr='popularity', consider='left', top_k=3)

# %% [markdown]
# Behind The Scenes: Notice how PD-Explain keeps track of the operations and steps

# %%
print(f'operation type: {popular_songs_df.operation.type}, source DF of operation: {popular_songs_df.operation.source_name}')

# %% [markdown]
# Applying a filter, to only select very popular songs (popularity more than 75), their names and release decade, by Drake:

# %% [markdown]
# Joining all of the decades when drake performed with the DF of very popular songs by drake:

# %%
drake_popular_decades = drake_very_popular.join(drake_decades, on=['main_artist', 'decade'], how='inner')
drake_popular_decades
