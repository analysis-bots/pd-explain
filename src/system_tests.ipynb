# %%
import pandas as pd
import pd_explain

songs_df = (pd.read_csv(r"C:\Users\itaye\Desktop\pdexplain\pd-explain\Examples\Datasets\spotify_all.csv"))
songs_df.describe()
# Out:
# C:\Users\itaye\AppData\Local\Temp\ipykernel_29908\1401922944.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# usetex-False
#         acousticness   danceability         energy       explicit  \
# count  174389.000000  174389.000000  174389.000000  174389.000000
# mean        0.499228       0.536758       0.482721       0.068135
# std         0.379936       0.176025       0.272685       0.251978
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.087700       0.414000       0.249000       0.000000
# ...

# %%
popular_songs = songs_df[songs_df['popularity'] > 65]

# %%
popular_songs.describe()
# Out:
#        acousticness  danceability       energy     explicit  instrumentalness  \
# count   7071.000000   7071.000000  7071.000000  7071.000000       7071.000000
# mean       0.253778      0.631681     0.625539     0.308584          0.029529
# std        0.272732      0.159726     0.199427     0.461942          0.132177
# min        0.000000      0.000000     0.000020     0.000000          0.000000
# 25%        0.031550      0.532000     0.494000     0.000000          0.000000
# 50%        0.145000      0.645000     0.645000     0.000000          0.000001
# 75%        0.405000      0.747000     0.776000     1.000000          0.000175
# max        0.995000      0.980000     1.000000     1.000000          1.000000
#
#                key     liveness     loudness         mode   popularity  \
# count  7071.000000  7071.000000  7071.000000  7071.000000  7071.000000
# mean      5.207184     0.178601    -7.224839     0.640645    71.846415
# ...

# %%
subset_of_columns = songs_df[['acousticness', 'name', 'main_artist', 'popularity']]

# %%
subset_of_columns.explain()
# Out:
# no operation was found.

# %%
popular_songs.explain()
# Out:
# C:\Users/itaye/Desktop/pdexplain/FEDEx_Generator-1/src\fedex_generator\Operations\Filter.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df[column] = numeric_df[column].map(items_map)
# C:\Users/itaye/Desktop/pdexplain/FEDEx_Generator-1/src\fedex_generator\Operations\Filter.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_df[column] = numeric_df[column].map(items_map)
# ...

# %%
type(popular_songs['popularity'])
# Out:
# pandas.core.series.Series
